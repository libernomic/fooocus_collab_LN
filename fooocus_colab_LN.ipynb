# %% [markdown]
# <a href="https://colab.research.google.com/github/libernomic/fooocus_collab_LN/blob/main/fooocus_colab_LN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 70.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.17.0
#     Uninstalling pygit2-1.17.0:
#       Successfully uninstalled pygit2-1.17.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6725 (delta 2), reused 0 (delta 0), pack-reused 6721 (from 3)
# Receiving objects: 100% (6725/6725), 33.26 MiB | 35.22 MiB/s, done.
# Resolving deltas: 100% (3878/3878), done.
# /content/Fooocus

# %%
# !wget -O /content/Fooocus/models/checkpoints/epicrealismXL_vxivEyecandyRealism.safetensors https://huggingface.co/libernomic/epiCRealism-XL/resolve/main/epicrealismXL_vxivEyecandyRealism.safetensors
# Out:
# --2025-02-16 21:54:32--  https://huggingface.co/libernomic/epiCRealism-XL/resolve/main/epicrealismXL_vxivEyecandyRealism.safetensors
# Resolving huggingface.co (huggingface.co)... 18.239.50.80, 18.239.50.103, 18.239.50.49, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.80|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget -O /content/Fooocus/models/checkpoints/flux1DevHyperNF4Flux1DevBNB_flux1DevHyperNF4.safetensors https://civitai.com/api/download/models/819165?type=Model&format=SafeTensor&size=full&fp=nf4
# Out:
# --2025-02-16 21:57:52--  https://civitai.com/api/download/models/819165?type=Model
# Resolving civitai.com (civitai.com)... 104.22.19.237, 172.67.12.143, 104.22.18.237, ...
# Connecting to civitai.com (civitai.com)|104.22.19.237|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/98099/flux1DevHyper8steps.tyFV.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22flux1DevHyperNF4Flux1DevBNB_flux1DevHyperNF4.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20250216/us-east-1/s3/aws4_request&X-Amz-Date=20250216T215753Z&X-Amz-SignedHeaders=host&X-Amz-Signature=2f81a9a773ebc876604dbc93fdb22a09eca6e8015313575de041b3b9ec1142c4 [following]
# ...

# %%
# !wget -O /content/Fooocus/models/loras/Perfect20v2.safetensors https://huggingface.co/Artazar/Lora/resolve/main/Perfect%20Hands%20v2.safetensors
# Out:
# --2025-02-16 22:40:07--  https://huggingface.co/Artazar/Lora/resolve/main/Perfect%20Hands%20v2.safetensors
# Resolving huggingface.co (huggingface.co)... 18.239.50.16, 18.239.50.103, 18.239.50.80, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.16|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python entry_with_update.py --share --always-high-vram
# Out:
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 15095 MB, total RAM 12979 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# Running on local URL:  http://127.0.0.1:7865
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# model_type EPS
# UNet ADM Dimension 2816
# Running on public URL: https://8f0dd33ffebf8344e2.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using pytorch attention in VAE
# ...
